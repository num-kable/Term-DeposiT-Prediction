# %%
#Importing libraries
import pandas as pd
import numpy as np

# %%
#importing  Visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import dataset 
df = pd.read_csv(r"C:\Users\Numaira\Desktop\ML\Evoastra\2.csv",sep=';')
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
#checking the shape of the data 
print(df.shape)
# Out:
# (41188, 21)

# %%
#checking null values 
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
#dropping the duration column 
df = df.drop('duration', axis = 1)
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign  pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon         1    999         0  nonexistent           1.1
# 1   may         mon         1    999         0  nonexistent           1.1
# 2   may         mon         1    999         0  nonexistent           1.1
# 3   may         mon         1    999         0  nonexistent           1.1
# 4   may         mon         1    999         0  nonexistent           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
print(df.shape)
# Out:
# (41188, 20)

# %%
#Data Visualization (AGE)
plt.hist(df['age'], bins=20,edgecolor = 'black')
plt.title ('Distribution of Customer age')
plt.xlabel ('Age')
plt.ylabel('frequency') 
plt.show()

# %%
#Data Visualization (JOB)
plt.figure(figsize=(12,6))
sns.countplot(x='job',data=df)
plt.title (' Count of customer by job')
plt.xlabel ('job')
plt.ylabel('Count') 
plt.xticks(rotation=45)
plt.show()

# %%
#getting proportion of different categories in contact, poutcome
marital_status_counts =df['marital'].value_counts()
plt.pie(marital_status_counts, labels= marital_status_counts.index,autopct='%1.1f%%',startangle = 90)
plt.title ('Marital Status Distribution')
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.countplot(data=df,x='education', hue ='job')
plt.title('Distribution of Job categories across education level')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# standard scaler 
 ##Backup
df_ready = df.copy()
    
## Importing important Libraries 
from sklearn.preprocessing import StandardScaler

##Initialization
scaler = StandardScaler()
    
## Making a list of numerical columns 
num_cols = [ 'age','campaign','pdays','previous']

## Scaling 
df_ready[num_cols] = scaler.fit_transform(df_ready[num_cols])
df_ready.head()
# Out:
#         age        job  marital    education  default housing loan    contact  \
# 0  1.533034  housemaid  married     basic.4y       no      no   no  telephone
# 1  1.628993   services  married  high.school  unknown      no   no  telephone
# 2 -0.290186   services  married  high.school       no     yes   no  telephone
# 3 -0.002309     admin.  married     basic.6y       no      no   no  telephone
# 4  1.533034   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  campaign     pdays  previous     poutcome  emp.var.rate  \
# 0   may         mon -0.565922  0.195414 -0.349494  nonexistent           1.1
# 1   may         mon -0.565922  0.195414 -0.349494  nonexistent           1.1
# 2   may         mon -0.565922  0.195414 -0.349494  nonexistent           1.1
# 3   may         mon -0.565922  0.195414 -0.349494  nonexistent           1.1
# 4   may         mon -0.565922  0.195414 -0.349494  nonexistent           1.1
#
# ...

# %%
# Dealing with categorical columns 

## List of categorical columns 
cat_cols = ['job','marital','education','default',
            'housing','loan','contact','month','day_of_week','poutcome']

## Encoding 
df_ready = pd.get_dummies(data = df_ready, columns = cat_cols)

##Encoding target variable 
df_ready['y'] = df_ready['y'].apply( lambda x : 1 if x == 'yes' else  0)
df_ready.head()
# Out:
#         age  campaign     pdays  previous  emp.var.rate  cons.price.idx  \
# 0  1.533034 -0.565922  0.195414 -0.349494           1.1          93.994
# 1  1.628993 -0.565922  0.195414 -0.349494           1.1          93.994
# 2 -0.290186 -0.565922  0.195414 -0.349494           1.1          93.994
# 3 -0.002309 -0.565922  0.195414 -0.349494           1.1          93.994
# 4  1.533034 -0.565922  0.195414 -0.349494           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  y  ...  month_oct  month_sep  \
# 0          -36.4      4.857       5191.0  0  ...          0          0
# 1          -36.4      4.857       5191.0  0  ...          0          0
# 2          -36.4      4.857       5191.0  0  ...          0          0
# 3          -36.4      4.857       5191.0  0  ...          0          0
# 4          -36.4      4.857       5191.0  0  ...          0          0
#
#    day_of_week_fri  day_of_week_mon  day_of_week_thu  day_of_week_tue  \
# ...

# %%
#printing the shape of data 
print(df_ready.shape)
# Out:
# (41188, 63)

# %%
# seperating input and output features 

## Input features 
features = df_ready.drop('y', axis = 1)
    
## Target 
target = df_ready['y']

# %%
# Train test split 
from sklearn.model_selection import train_test_split

X_train, X_test,y_train, y_test = train_test_split(features ,target ,
                                                   test_size = 0.2, random_state = 7)

# %%
# Perform cross-validation
cv_scores = cross_val_score(lr, features, target, cv=5)  # 5-fold cross-validation

# %%
#Model Training 

from sklearn.model_selection import ShuffleSplit, cross_val_score
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(max_iter = 10e6)

#fitting the model 
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000000.0,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Assuming you have already made predictions for the first 25 customers
new_customer_prediction = lr.predict(X_test.iloc[:25])

# Interpret and print the results
print("Predictions for the first 25 customers:")
for i, prediction in enumerate(new_customer_prediction):
    result = 'YES' if prediction == 1 else 'NO'
    print(f"Customer {i + 1} will take subscription: {result}")
# Out:
# Predictions for the first 25 customers:
# Customer 1 will take subscription: NO
# Customer 2 will take subscription: NO
# Customer 3 will take subscription: NO
# Customer 4 will take subscription: NO
# Customer 5 will take subscription: NO
# Customer 6 will take subscription: NO
# Customer 7 will take subscription: NO
# Customer 8 will take subscription: YES
# Customer 9 will take subscription: NO
# Customer 10 will take subscription: NO
# Customer 11 will take subscription: NO
# Customer 12 will take subscription: NO
# Customer 13 will take subscription: YES
# Customer 14 will take subscription: NO
# Customer 15 will take subscription: NO
# Customer 16 will take subscription: NO
# Customer 17 will take subscription: NO
# Customer 18 will take subscription: NO
# Customer 19 will take subscription: NO
# Customer 20 will take subscription: NO
# Customer 21 will take subscription: NO
# Customer 22 will take subscription: NO
# Customer 23 will take subscription: NO
# ...

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score

#  trained your model and made predictions
y_pred = lr.predict(X_test)

#  accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(conf_matrix)

# classification report
class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)

# cross-validation score
print("\nCross-Validation Scores:", cv_scores)
# Out:
# Accuracy: 0.90
#
# Confusion Matrix:
# [[7241   92]
#  [ 711  194]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      7333
#            1       0.68      0.21      0.33       905
#
#     accuracy                           0.90      8238
#    macro avg       0.79      0.60      0.64      8238
# weighted avg       0.89      0.90      0.88      8238
#
#
# Cross-Validation Scores: [0.8873513  0.8873513  0.88856519 0.58431468 0.46886002]

# %%
# Generate the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Create a heatmap to visualize the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Not Subscribed', 'Subscribed'],
            yticklabels=['Not Subscribed', 'Subscribed'])

plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
#getting proportion of different categories in target variable 
df['y'].value_counts()
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64
